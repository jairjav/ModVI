# %% [markdown]
# <a href="https://colab.research.google.com/github/jairjav/ModVI/blob/main/tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Modulo VI;**
#
# **Tarea 2 **; Word Embeddings
#
# Jair Joaquin Ahumada Valencia
#
# **Instrucciones; **
# Escribe o selecciona 10 oraciones de tu campo de dominio
# Calcula los embeddings de esas oraciones
# Visualiza esos embeddings
# Calcula la distancia conseno entre ellas
#
# **Topico de Frases elegidas**; CRM
#
# **Juastificacion del topico;** Es mi campo de expertise profesional

# %%
# !pip install sentence_transformers
import numpy  as np
from sentence_transformers import SentenceTransformer

model= SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 4.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
CRM= ['La creacion de HTML dinamico, permite atraer la atncion de cada cliente dependiendo sus preferencias de consumo',
      'La implementacion de joruneys en acoustic campaing permite tener un ciclo de vida del cliente desde su adopcion hasta consumo',
      'El uso de email, sms y push nos permite vencer la monotonia en la forma de contactar al cliente',
      'Tener una persona enfocada por producto bancario permite tener personas especializadas que ofrezcan mejores estrategias',
      'El implementar un gobierno de contacto ayuda a saber quienes y de que forma interactuan con nosotros y deducir el por que algunos no les parecemos opcion atractiva',
      'La automatizacion de procesos repetitivos ayuda a enfocar esfuerzos y recursos en tareas complejas en el area',
      'La segmentacion de clientes en SQL me permite identificar patrones de comportamiento de los clientes',
      'El uso de acoustic campaing es ideal para gestionar de manera optima la comunicacion ida y vuelta del cliente con nosotros',
      'La optimizacion de los flujos de trabajo es una buena herramienta para reducir tiempos de ejecucion y mejorar tiempos de respuesta',
      'El analisis de datos permite tomar decisiones basadas en realidades']


embedding= model.encode(CRM)

print(embedding)
# Out:
# [[-0.06488155 -0.02472882 -0.25890803 ... -0.09018458  0.42409062
#   -0.10179613]
#  [ 0.39423147 -0.0288268   0.14565973 ... -0.04107644  0.11730032
#    0.52289957]
#  [-0.42588887 -0.27157313 -0.12304543 ...  0.12163725  0.1671996
#    0.38142714]
#  ...
#  [ 0.42631674 -0.12045258  0.30896813 ... -0.03692824 -0.25842792
#    0.41306162]
#  [-0.00257294 -0.22434464  0.09661028 ... -0.27881232  0.2621068
#    0.2960205 ]
#  [ 0.01209707  0.38494626 -0.31001234 ... -0.26511306  0.01777772
#    0.3490258 ]]

# %%
embedding.shape
# Out:
# (10, 384)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#
sns.heatmap(embedding[0].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

sns.heatmap(embedding[1].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

sns.heatmap(embedding[2].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[3].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[4].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[5].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[6].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[7].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[8].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()


sns.heatmap(embedding[9].reshape(-1,384),cmap="Greys",center=0,square=False)
plt.gcf().set_size_inches(10,1)
plt.axis('off')
plt.show()

# %%
from scipy.spatial.distance import cosine
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import losses
from scipy.stats import norm

# %%
#Dot Product

print("Distance 0-1:", np.dot(embedding[0], embedding[1]))
print("Distance 0-2:", np.dot(embedding[0], embedding[2]))
print("Distance 0-3:", np.dot(embedding[0], embedding[3]))
print("Distance 0-4:", np.dot(embedding[0], embedding[4]))
print("Distance 0-5:", np.dot(embedding[0], embedding[5]))
print("Distance 0-6:", np.dot(embedding[0], embedding[6]))
print("Distance 0-7:", np.dot(embedding[0], embedding[7]))
print("Distance 0-8:", np.dot(embedding[0], embedding[8]))
print("Distance 0-9:", np.dot(embedding[0], embedding[9]))

print("Distance 1-2:", np.dot(embedding[1], embedding[2]))
print("Distance 1-3:", np.dot(embedding[1], embedding[3]))
print("Distance 1-4:", np.dot(embedding[1], embedding[4]))
print("Distance 1-5:", np.dot(embedding[1], embedding[5]))
print("Distance 1-6:", np.dot(embedding[1], embedding[6]))
print("Distance 1-7:", np.dot(embedding[1], embedding[7]))
print("Distance 1-8:", np.dot(embedding[1], embedding[8]))
print("Distance 1-9:", np.dot(embedding[1], embedding[9]))

print("Distance 2-3:", np.dot(embedding[2], embedding[3]))
print("Distance 2-4:", np.dot(embedding[2], embedding[4]))
print("Distance 2-5:", np.dot(embedding[2], embedding[5]))
print("Distance 2-6:", np.dot(embedding[2], embedding[6]))
print("Distance 2-7:", np.dot(embedding[2], embedding[7]))
print("Distance 2-8:", np.dot(embedding[2], embedding[8]))
print("Distance 2-9:", np.dot(embedding[2], embedding[9]))

print("Distance 3-4:", np.dot(embedding[3], embedding[4]))
print("Distance 3-5:", np.dot(embedding[3], embedding[5]))
print("Distance 3-6:", np.dot(embedding[3], embedding[6]))
print("Distance 3-7:", np.dot(embedding[3], embedding[7]))
print("Distance 3-8:", np.dot(embedding[3], embedding[8]))
print("Distance 3-9:", np.dot(embedding[3], embedding[9]))

print("Distance 4-5:", np.dot(embedding[4], embedding[5]))
print("Distance 4-6:", np.dot(embedding[4], embedding[6]))
print("Distance 4-7:", np.dot(embedding[4], embedding[7]))
print("Distance 4-8:", np.dot(embedding[4], embedding[8]))
print("Distance 4-9:", np.dot(embedding[4], embedding[9]))

print("Distance 5-6:", np.dot(embedding[5], embedding[6]))
print("Distance 5-7:", np.dot(embedding[5], embedding[7]))
print("Distance 5-8:", np.dot(embedding[5], embedding[8]))
print("Distance 5-9:", np.dot(embedding[5], embedding[9]))

print("Distance 6-7:", np.dot(embedding[6], embedding[7]))
print("Distance 6-8:", np.dot(embedding[6], embedding[8]))
print("Distance 6-9:", np.dot(embedding[6], embedding[9]))

print("Distance 7-8:", np.dot(embedding[7], embedding[8]))
print("Distance 7-9:", np.dot(embedding[7], embedding[9]))

print("Distance 8-9:", np.dot(embedding[8], embedding[9]))
# Out:
# Distance 0-1: 16.494026
# Distance 0-2: 18.881294
# Distance 0-3: 16.976192
# Distance 0-4: 14.5342655
# Distance 0-5: 15.564526
# Distance 0-6: 16.487736
# Distance 0-7: 16.328945
# Distance 0-8: 16.40068
# Distance 0-9: 17.276318
# Distance 1-2: 20.78254
# Distance 1-3: 16.14307
# Distance 1-4: 15.587789
# Distance 1-5: 15.904991
# Distance 1-6: 13.168433
# Distance 1-7: 33.411133
# Distance 1-8: 18.820063
# Distance 1-9: 16.919231
# Distance 2-3: 15.347893
# Distance 2-4: 18.989935
# Distance 2-5: 14.028257
# Distance 2-6: 17.412968
# Distance 2-7: 21.843575
# Distance 2-8: 17.69458
# Distance 2-9: 14.660138
# Distance 3-4: 15.606793
# Distance 3-5: 16.569649
# Distance 3-6: 20.625666
# Distance 3-7: 14.5682335
# Distance 3-8: 17.699022
# Distance 3-9: 14.991974
# Distance 4-5: 17.55167
# Distance 4-6: 12.861754
# Distance 4-7: 14.377966
# Distance 4-8: 16.71841
# Distance 4-9: 13.8693695
# Distance 5-6: 13.223484
# Distance 5-7: 15.386528
# Distance 5-8: 17.297005
# ...

# %%
#Cosine Distance


#
import warnings
warnings.filterwarnings('ignore')
from scipy.spatial.distance import cosine
def cosine_distance(embedding1, embedding2):
    return cosine(embedding1, embedding2)

print("Distance 0-1:", cosine_distance(embedding[0], embedding[1]))
print("Distance 0-2:", cosine_distance(embedding[0], embedding[2]))
print("Distance 0-3:", cosine_distance(embedding[0], embedding[3]))
print("Distance 0-4:", cosine_distance(embedding[0], embedding[4]))
print("Distance 0-5:", cosine_distance(embedding[0], embedding[5]))
print("Distance 0-6:", cosine_distance(embedding[0], embedding[6]))
print("Distance 0-7:", cosine_distance(embedding[0], embedding[7]))
print("Distance 0-8:", cosine_distance(embedding[0], embedding[8]))
print("Distance 0-9:", cosine_distance(embedding[0], embedding[9]))
print("Distance 1-2:", cosine_distance(embedding[1], embedding[2]))
print("Distance 1-3:", cosine_distance(embedding[1], embedding[3]))
print("Distance 1-4:", cosine_distance(embedding[1], embedding[4]))
print("Distance 1-5:", cosine_distance(embedding[1], embedding[5]))
print("Distance 1-6:", cosine_distance(embedding[1], embedding[6]))
print("Distance 1-7:", cosine_distance(embedding[1], embedding[7]))
print("Distance 1-8:", cosine_distance(embedding[1], embedding[8]))
print("Distance 1-9:", cosine_distance(embedding[1], embedding[9]))
print("Distance 2-3:", cosine_distance(embedding[2], embedding[3]))
print("Distance 2-4:", cosine_distance(embedding[2], embedding[4]))
print("Distance 2-5:", cosine_distance(embedding[2], embedding[5]))
print("Distance 2-6:", cosine_distance(embedding[2], embedding[6]))
print("Distance 2-7:", cosine_distance(embedding[2], embedding[7]))
print("Distance 2-8:", cosine_distance(embedding[2], embedding[8]))
print("Distance 2-9:", cosine_distance(embedding[2], embedding[9]))
print("Distance 3-4:", cosine_distance(embedding[3], embedding[4]))
print("Distance 3-5:", cosine_distance(embedding[3], embedding[5]))
print("Distance 3-6:", cosine_distance(embedding[3], embedding[6]))
print("Distance 3-7:", cosine_distance(embedding[3], embedding[7]))
print("Distance 3-8:", cosine_distance(embedding[3], embedding[8]))
print("Distance 3-9:", cosine_distance(embedding[3], embedding[9]))
print("Distance 4-5:", cosine_distance(embedding[4], embedding[5]))
print("Distance 4-6:", cosine_distance(embedding[4], embedding[6]))
print("Distance 4-7:", cosine_distance(embedding[4], embedding[7]))
print("Distance 4-8:", cosine_distance(embedding[4], embedding[8]))
print("Distance 4-9:", cosine_distance(embedding[4], embedding[9]))
print("Distance 5-6:", cosine_distance(embedding[5], embedding[6]))
print("Distance 5-7:", cosine_distance(embedding[5], embedding[7]))
print("Distance 5-8:", cosine_distance(embedding[5], embedding[8]))
print("Distance 5-9:", cosine_distance(embedding[5], embedding[9]))
print("Distance 6-7:", cosine_distance(embedding[6], embedding[7]))
print("Distance 6-8:", cosine_distance(embedding[6], embedding[8]))
print("Distance 6-9:", cosine_distance(embedding[6], embedding[9]))
print("Distance 7-8:", cosine_distance(embedding[7], embedding[8]))
print("Distance 7-9:", cosine_distance(embedding[7], embedding[9]))
print("Distance 8-9:", cosine_distance(embedding[8], embedding[9]))
# Out:
# Distance 0-1: 0.49094605445861816
# Distance 0-2: 0.3825266361236572
# Distance 0-3: 0.4345591068267822
# Distance 0-4: 0.4716896414756775
# Distance 0-5: 0.43047910928726196
# Distance 0-6: 0.5126269161701202
# Distance 0-7: 0.5086693465709686
# Distance 0-8: 0.4344547986984253
# Distance 0-9: 0.4528249502182007
# Distance 1-2: 0.4365917444229126
# Distance 1-3: 0.5542707145214081
# Distance 1-4: 0.5303020477294922
# Distance 1-5: 0.5175577998161316
# Distance 1-6: 0.6773195564746857
# Distance 1-7: 0.16661608219146729
# Distance 1-8: 0.4620218276977539
# Distance 1-9: 0.5557843148708344
# Distance 2-3: 0.5509620010852814
# Distance 2-4: 0.3936730623245239
# Distance 2-5: 0.5491158962249756
# Distance 2-6: 0.5478726625442505
# Distance 2-7: 0.42266637086868286
# Distance 2-8: 0.4640390872955322
# Distance 2-9: 0.5921498239040375
# Distance 3-4: 0.49247485399246216
# Distance 3-5: 0.4575809836387634
# Distance 3-6: 0.45454829931259155
# Distance 3-7: 0.6078335344791412
# ...

# %% [markdown]
# **Intepretaciones de los Resultados**
#
# **Dot Product** ; De acuerdo con esta medicion no tenemos realmente frases parecidas entre si, pero si nos apegamos a un interpretacion con base a los resultados entre ellas, nos diria que la frase 1:" La implementacion de joruneys en acoustic campaing permite tener un ciclo de vida del cliente desde su adopcion hasta su consumo" y la frase 7 : El uso de acoustic campaing es ideal para gestionar de manera optima la comunicacion ida y vuelta del cliente y nosotros", Son las mas parecidas(Distance 1-7: 33.411133).
#
#
# **Coseno; **Esta similitud entre la frase 1 y 7 tambien la encontramos en el coseno (0.1666).
#
# La farase 0 y 6 tambien parece tener similitud 0.3825, aunque se mencionan herramientas diferentes compartel el objetivo.
#
# En cuasnto a las menos parecidas por el criterio de Coseno; Tenemos las frases 6 y 7(0.7024), en una enfoque hacia la segmentacion y en la otra mas hacia el lado de marketing
#
# Tambien podria ser la 1 y 6 ; No son tan parecidas( 0.5126) de acuerdo con el coseno, en una me refiero a personaloizaciones y en otra a automatizaciones.

# %% [markdown]
# **Conclusion**
#
# A pesar de que a simple vista en el Dot product pareciera no haber tanta similitud entre las frases que elegi, de hecho pareciera ser que no tienen practicamente nada que ver, al utilizar el coseno podemos encontrar similitudes mas precisas como las que describi arriba sobre el objetivo de las frases en el coseno. Pudiera inferir que aunque el coseno me parecio una forma de comparar mas certera, yo ocuparia ambas ya que inclusive con valores altos en Dot producrt pudiera no haber tanta relacion. Las considero complementarias.
